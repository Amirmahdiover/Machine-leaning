# %% [markdown]
# Importing

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %% [markdown]
# Opening data set

# %%
with open('Position_Salaries.csv') as r:
    my_csv=pd.read_csv(r)
x=my_csv.iloc[:,1:2].values
y=my_csv.iloc[:,-1].values

# %% [markdown]
# Training simple linear regression

# %%
lin_reg=LinearRegression()
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# Training Polynomial linear regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_c=PolynomialFeatures(degree=4)
x_poly=poly_c.fit_transform(x)
poly_lin=LinearRegression()
poly_lin.fit(x_poly,y)
x_poly
# Out:
# array([[1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00],
#        [1.000e+00, 2.000e+00, 4.000e+00, 8.000e+00, 1.600e+01],
#        [1.000e+00, 3.000e+00, 9.000e+00, 2.700e+01, 8.100e+01],
#        [1.000e+00, 4.000e+00, 1.600e+01, 6.400e+01, 2.560e+02],
#        [1.000e+00, 5.000e+00, 2.500e+01, 1.250e+02, 6.250e+02],
#        [1.000e+00, 6.000e+00, 3.600e+01, 2.160e+02, 1.296e+03],
#        [1.000e+00, 7.000e+00, 4.900e+01, 3.430e+02, 2.401e+03],
#        [1.000e+00, 8.000e+00, 6.400e+01, 5.120e+02, 4.096e+03],
#        [1.000e+00, 9.000e+00, 8.100e+01, 7.290e+02, 6.561e+03],
#        [1.000e+00, 1.000e+01, 1.000e+02, 1.000e+03, 1.000e+04]])

# %% [markdown]
# Visualization the simple linear regression

# %%
plt.scatter(x,y,color='red')
plt.plot(x,lin_reg.predict(x),color='blue')
plt.title('Linear regression')
plt.xlabel('Level of work')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Visualization the polynomial linear regression

# %%
plt.scatter(x,y,color='red')
plt.plot(x,poly_lin.predict(x_poly),color='green')
plt.title('Polynomial linear regression')
plt.xlabel('Level of work')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Predicting a data with Linear Regression

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# Predicting a data with Polynomial linear regression

# %%
poly_lin.predict(poly_c.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])
