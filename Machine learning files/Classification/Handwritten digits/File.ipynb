# %% [markdown]
# Importing Libraries

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from matplotlib.pyplot import matshow
import numpy as np
from PIL import Image
from numpy import asarray

# %% [markdown]
# Dataset

# %%
digits=load_digits()
print(digits.data[173])
# Out:
# [ 0.  0.  7. 16. 16. 16. 13.  0.  0.  0.  8.  9.  8. 15. 15.  0.  0.  0.
#   0.  0.  4. 16.  7.  0.  0.  0.  4.  8. 12. 16.  5.  0.  0.  3. 16. 16.
#  16. 14.  7.  0.  0.  0.  3.  8. 16.  3.  0.  0.  0.  0.  0. 15. 13.  0.
#   0.  0.  0.  0.  7. 16.  3.  0.  0.  0.]

# %% [markdown]
# 5 Example of digits in dataset

# %%
plt.gray()
for item in range(5):  
    plt.matshow(digits.images[item])

# %% [markdown]
# Splitting the data into training and test dataset

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(digits.data,digits.target,test_size=0.2)

# %%
len(x_train)
# Out:
# 1437

# %%
len(x_test)
# Out:
# 360

# %% [markdown]
# Training the model

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression(max_iter=200)
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=200)

# %% [markdown]
# Evaluating score of model

# %%
classifier.score(x_test,y_test)
# Out:
# 0.9638888888888889

# %% [markdown]
# Test the model

# %%
classifier.predict([digits.data[99]])
# Out:
# array([1])

# %%
digits.target[99]
# Out:
# 1

# %%
plt.matshow(digits.images[99])

# %% [markdown]
# Predicting new image

# %%
image=Image.open('Untitled-2.png')
data=asarray(image)
data=np.array(image.convert('L'))
data=data.reshape(64,)

# %%
import matplotlib.pyplot as plt
from matplotlib import image
image2=image.imread('Untitled-2.png')
plt.imshow(image2)

# %%
classifier.predict([data])
# Out:
# array([5])
