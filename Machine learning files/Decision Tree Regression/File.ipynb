# %% [markdown]
# Importing Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Importing the dataset

# %%
with open('Position_Salaries.csv') as r:
    my_csv=pd.read_csv(r)
x=my_csv.iloc[:,1:-1].values
y=my_csv.iloc[:,2:].values

# %% [markdown]
# Training the Decision Tree Regression model on the whole dataset

# %%
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor(random_state=0)
regressor.fit(x,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# Predicting a new result

# %%
regressor.predict([[6.5]])
# Out:
# array([150000.])

# %% [markdown]
# Visualising the Decision Tree Regression results (higher resolution)

# %%
x_grid=np.arange(min(x),max(x),0.1)
x_grid=x_grid.reshape((len(x_grid),1))
plt.scatter(x,y,color='red')
plt.plot(x_grid,regressor.predict(x_grid),color='blue')
plt.title('Decision Tree Regression')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\amirmahdi\AppData\Local\Temp\ipykernel_15884\257096403.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid=np.arange(min(x),max(x),0.1)
